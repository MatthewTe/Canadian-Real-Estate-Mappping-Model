# %%
# Importing the necessary packages: 
import geopandas as gpd
import pandas as pd 
import matplotlib.pyplot as plt

# %%
shp = gpd.read_file('City_Shapefiles/Sub_Sector_Boundary/Sub_Sector_Boundary.shp')
# Confirming file integrity: 
shp.head()
# Out:
#                SECTOR SUBSECTOR     SHAPEarea      SHAPElen  OBJECTID  \
# 0  Glenmore - Clifton        3C  3.834846e+06   9415.574327        61
# 1             Rutland        5D  8.205023e+05   4325.956725        70
# 2        Central City        4B  7.289166e+05   6786.585795        48
# 3        Central City        4C  4.290641e+06  10504.821170        45
# 4    McKinley Landing        1B  1.434383e+07  22153.572309        54
#
#                                             geometry
# 0  POLYGON ((324604.3720000004 5530156.207, 32460...
# 1  POLYGON ((327781.9309999999 5529400.1, 327775....
# 2  POLYGON ((322948.7879999997 5528547.811000001,...
# 3  POLYGON ((326347.8200000003 5529092.220000001,...
# 4  POLYGON ((326339.3289999999 5533739.541999999,...

# %%
# Plotting the grid:
shp.plot()

# %%
shp
# Out:
#                       SECTOR SUBSECTOR     SHAPEarea      SHAPElen  OBJECTID  \
# 0         Glenmore - Clifton        3C  3.834846e+06   9415.574327        61
# 1                    Rutland        5D  8.205023e+05   4325.956725        70
# 2               Central City        4B  7.289166e+05   6786.585795        48
# 3               Central City        4C  4.290641e+06  10504.821170        45
# 4           McKinley Landing        1B  1.434383e+07  22153.572309        54
# 5               Central City        4A  6.689631e+06  18054.876094       139
# 6                    Rutland        5C  5.113421e+05   4300.888144       112
# 7              Pandosy - KLO        7A  4.222912e+06  10941.246017        43
# 8              Pandosy - KLO        7B  6.696634e+06  12417.424636        42
# 9   North Mission - Crawford        9A  5.444049e+06  14621.716521       110
# 10                   Rutland        5A  6.549177e+06  16823.832060        71
# ...
